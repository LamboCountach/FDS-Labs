# %% [markdown]
# # Inf2 - Foundations of Data Science
# ## S2 Week 01: Logistic regression

# %% [markdown]
# **Learning outcomes:** In this lab you will learn about logistic regression, interpretation of logistic regression coefficients and generating confidence intervals for logistic regression coefficients. By the end of this lab you should be able to:
#
# - identify what transformations would be helpful to variables before applying logistic regression
# - apply logistic regression to a dataset
# - interpret the coefficients from application of logistic regression
# - apply the bootstrap to logistic regression to obtain confidence intervals
# - interpret the confidence intervals
#
# **Remark:** The lecture topic on "Logistic regression" will be helpful background for this lab.
#
# **Data information:** We will look at the credit approval dataset, which we have already looked at during the lectures, and we will try to reconstruct the results ourselves. The dataset was originally published on the [UCI repository with the attribute names and values changed to meaningless symbols](https://archive.ics.uci.edu/ml/datasets/credit+approval). We have used [this version of the dataset](https://github.com/KiranmayiR/Credit_Shiny), in which the attribute names have been inferred. However, we have changed some attributes.

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## A. Prepare the data
#
# Our goal is to use logistic regression to understand what features are most important in the decision of giving an applicant a credit.
#
# **Exercise 01:** The first step is to clean our dataset.
# - Load the dataset.
# - Display the first 20 entries.
# - Remove all entries with `NaN` values. (Hint: This data set has `?` characters instead of `NaN values).
# - Replace all non-numeric values by reasonable numeric values. Hint: we suggest you interpret `t` as `True` and `f` as `False`.
# - For simplicity, drop the `ZipCode` column.
#
# **Remark:** Zip codes can have an impact on credit approval. For example, ML algorithms trained on racially biased data, where the information about race has been dropped, can still learn the bias, as people from same ethnic background tend to live in the same area. However, for logistic regression the zip code is unlikely provide any information, as two zip codes that differ by a single digit can be many miles apart. We could consider whether this is the case if we used $k$-Nearest-Neighbours.

# %%
# Your code
c_a = pd.read_csv(os.path.join(os.getcwd(),'datasets','Credit_Approval.csv'))

c_a.head(20)
# Out:
#    Gender    Age    Debt  YearsEmployed NoPriorDefault Employed  CreditScore  \
# 0       b  30.83   0.000          1.250              t        t            1
# 1       a  58.67   4.460          3.040              t        t            6
# 2       a  24.50   0.500          1.500              t        f            0
# 3       b  27.83   1.540          3.750              t        t            5
# 4       b  20.17   5.625          1.710              t        f            0
# 5       b  32.08   4.000          2.500              t        f            0
# 6       b  33.17   1.040          6.500              t        f            0
# 7       a  22.92  11.585          0.040              t        f            0
# 8       b  54.42   0.500          3.960              t        f            0
# 9       b  42.50   4.915          3.165              t        f            0
# 10      b  22.08   0.830          2.165              f        f            0
# 11      b  29.92   1.835          4.335              t        f            0
# 12      a  38.25   6.000          1.000              t        f            0
# 13      b  48.08   6.040          0.040              f        f            0
# 14      a  45.83  10.500          5.000              t        t            7
# 15      b  36.67   4.415          0.250              t        t           10
# 16      b  28.25   0.875          0.960              t        t            3
# 17      a  23.25   5.875          3.170              t        t           10
# 18      b  21.83   0.250          0.665              t        f            0
# 19      a  19.17   8.585          0.750              t        t            7
#
#    DriversLicense  ZipCode  Income Approved
# 0               f    202.0       0        +
# 1               f     43.0     560        +
# 2               f    280.0     824        +
# 3               t    100.0       3        +
# 4               f    120.0       0        +
# 5               t    360.0       0        +
# 6               t    164.0   31285        +
# 7               f     80.0    1349        +
# 8               f    180.0     314        +
# 9               t     52.0    1442        +
# 10              t    128.0       0        +
# 11              f    260.0     200        +
# 12              t      0.0       0        +
# 13              f      0.0    2690        +
# 14              t      0.0       0        +
# 15              t    320.0       0        +
# 16              t    396.0       0        +
# 17              f    120.0     245        +
# 18              t      0.0       0        +
# 19              f     96.0       0        +

# %%
c_a.dropna(inplace = True)
c_a.reset_index(drop=True, inplace=True)

def tf_conversion(x):
    if x == 't':
        return True
    elif x == 'f':
        return False

def approval_conversion(x):
    if x == '-':
        return 0
    elif x == '+':
        return 1

c_a['Gender'] = c_a['Gender'].apply(lambda x: 0 if x == 'a' else 1)
c_a['NoPriorDefault'] = c_a['NoPriorDefault'].apply(tf_conversion)
c_a['Employed'] = c_a['Employed'].apply(tf_conversion)
c_a['DriversLicense'] = c_a['DriversLicense'].apply(tf_conversion)
c_a['Approved'] = c_a['Approved'].apply(approval_conversion)

c_a = c_a.drop('ZipCode', axis=1)

c_a
# Out:
#      Gender    Age    Debt  YearsEmployed  NoPriorDefault  Employed  \
# 0         1  30.83   0.000           1.25            True      True
# 1         0  58.67   4.460           3.04            True      True
# 2         0  24.50   0.500           1.50            True     False
# 3         1  27.83   1.540           3.75            True      True
# 4         1  20.17   5.625           1.71            True     False
# ..      ...    ...     ...            ...             ...       ...
# 649       1  21.08  10.085           1.25           False     False
# 650       0  22.67   0.750           2.00           False      True
# 651       0  25.25  13.500           2.00           False      True
# 652       1  17.92   0.205           0.04           False     False
# 653       1  35.00   3.375           8.29           False     False
#
#      CreditScore  DriversLicense  Income  Approved
# 0              1           False       0         1
# 1              6           False     560         1
# 2              0           False     824         1
# 3              5            True       3         1
# 4              0           False       0         1
# ..           ...             ...     ...       ...
# 649            0           False       0         0
# 650            2            True     394         0
# 651            1            True       1         0
# 652            0           False     750         0
# 653            0            True       0         0
#
# [654 rows x 10 columns]

# %% [markdown]
# **Exercise 02:** Let's compare the values for the two genders. Compute the mean of the columns for each gender.

# %%
# Your code
gender_0 = c_a[c_a.Gender == 0]
gender_1 = c_a[c_a.Gender == 1]

for col in c_a.columns[1:]:
    print('Mean of the {} for gender 0: {}'.format(col, np.mean(gender_0[col])))
    print('Mean of the {} for gender 1: {}'.format(col, np.mean(gender_1[col])))
# Out:
# Mean of the Age for gender 0: 30.760985221674876
# Mean of the Age for gender 1: 31.94625277161863
# Mean of the Debt for gender 0: 5.090591133004925
# Mean of the Debt for gender 1: 4.713514412416851
# Mean of the YearsEmployed for gender 0: 1.8184975369458132
# Mean of the YearsEmployed for gender 1: 2.432172949002215
# Mean of the NoPriorDefault for gender 0: 0.5517241379310345
# Mean of the NoPriorDefault for gender 1: 0.5277161862527716
# Mean of the Employed for gender 0: 0.4876847290640394
# Mean of the Employed for gender 1: 0.41685144124168516
# Mean of the CreditScore for gender 0: 2.625615763546798
# Mean of the CreditScore for gender 1: 2.4412416851441243
# Mean of the DriversLicense for gender 0: 0.4236453201970443
# Mean of the DriversLicense for gender 1: 0.4789356984478936
# Mean of the Income for gender 0: 911.3891625615763
# Mean of the Income for gender 1: 1058.3458980044345
# Mean of the Approved for gender 0: 0.46798029556650245
# Mean of the Approved for gender 1: 0.44567627494456763

# %% [markdown]
# **Exercise 03:**
# - Create a pairplot of the data, giving approved and denied applications different colours.
# - As you can see there too many variables. Remove variables from the pairplot that you think are not displayed helpfully in a pairplot.

# %%
# Your code
sns.pairplot(c_a[['Age','Debt','YearsEmployed','CreditScore','Income','Approved']], hue = 'Approved')

# %% [markdown]
# ## B. Transform the dataset so logistic regression works better
#
# **Discussion:** We have already applied the log transform to datasets previously.
# - Can you remember why this can be helpful?
# - For which variables in your dataset would a log transform help? Have a look at the plot above.
# - Can you think of data points the log transform might not work for, and how the transform could be modified to fix this?

# %% [markdown]
# Your answer:

# %% [markdown]
# **Exercise 04:**
# - Replace the `Income` variable by transforming it with a function $f(x) = \log_{10} (x + 1)$ to give a version called `LogIncome`.
# - Repeat the above step with the `CreditScore` variable to give a log transformed version called `LogCreditScore`.
# - Plot a new pairplot to see the new distributions.

# %%
# Your code
def f(x):
    return np.log10(x+1)

c_a['Income'] = c_a['Income'].apply(f)
c_a['CreditScore'] = c_a['CreditScore'].apply(f)
c_a.rename(columns = {'Income':'LogIncome', 'CreditScore':'LogCreditScore'}, inplace = True)
c_a
# Out:
#      Gender    Age    Debt  YearsEmployed  NoPriorDefault  Employed  \
# 0         1  30.83   0.000           1.25            True      True
# 1         0  58.67   4.460           3.04            True      True
# 2         0  24.50   0.500           1.50            True     False
# 3         1  27.83   1.540           3.75            True      True
# 4         1  20.17   5.625           1.71            True     False
# ..      ...    ...     ...            ...             ...       ...
# 649       1  21.08  10.085           1.25           False     False
# 650       0  22.67   0.750           2.00           False      True
# 651       0  25.25  13.500           2.00           False      True
# 652       1  17.92   0.205           0.04           False     False
# 653       1  35.00   3.375           8.29           False     False
#
#      LogCreditScore  DriversLicense  LogIncome  Approved
# 0          0.301030           False   0.000000         1
# 1          0.845098           False   2.748963         1
# 2          0.000000           False   2.916454         1
# 3          0.778151            True   0.602060         1
# 4          0.000000           False   0.000000         1
# ..              ...             ...        ...       ...
# 649        0.000000           False   0.000000         0
# 650        0.477121            True   2.596597         0
# 651        0.301030            True   0.301030         0
# 652        0.000000           False   2.875640         0
# 653        0.000000            True   0.000000         0
#
# [654 rows x 10 columns]

# %% [markdown]
# ## C. Use sk-learn to run Logistic regression
#
# **Exercise 05:** Let's start with the simplest case of logistic regression. We want to know whether age alone is a good feature to predict whether someone receives a credit.
# - Use the `LogisticRegression()` to run logistic regression. (Hint: You will have to supply a numpy matrix of independent variables and a vector of response variables - the Nearest Neighbours lab may remind you how to do it.)
# - Store the fitted model.
# - Store the intercept and the coefficient of the model in `beta0` and `beta1`, respectively. Print the values.
# - Create a scatterplot, in which, to make it intelligible, you randomly sample 50 data points. The x-axis should be `Age` and the y-axis should be `Approved`.
# - Add a line plot to your figure that shows the probability predicted by the logistic regression. **Hint:** The sklearn `predict_proba()` function can be applied to the fitted model.

# %%
# Your code
approval = c_a['Approved']
feature_age = np.array(c_a['Age']).reshape(-1,1)

lr = LogisticRegression()

lr.fit(feature_age, approval)
beta0 = lr.intercept_[0]
beta1 = lr.coef_[0][0]

print('beta0: '+str(beta0))
print('beta1: '+str(beta1))

temp = c_a.sample(n=50, replace=True)
sampled_age, sampled_approval = temp['Age'], temp['Approved']
predicted_probabilities = lr.predict_proba(np.array(sampled_age).reshape(-1,1))[:,1] #store the predicted probability of each sample being approved
plt.plot(sampled_age, predicted_probabilities, c = 'r')
plt.scatter(sampled_age, sampled_approval)

plt.xlabel('Age')
plt.ylabel('Approval')
# Out:
# beta0: -1.124289487490623
# beta1: 0.02952008435059766
# Text(0, 0.5, 'Approval')

# %% [markdown]
# **Discussion:** Interpret the intercept `model.intercept_`, which is the same as $\hat\beta_0$ in the lecture notes. What quantity does it represent? Describe the characteristics of the customer for who the independent variables are all zero. Does such a customer exist?

# %% [markdown]
# Your answer:

# %% [markdown]
# **Exercise 06:** Above we have run the logistic regression on only one independent variable in order to be able to plot it in a figure. Now, run a logistic regression on the full data.

# %%
# Your code
approval = c_a['Approved']
X = c_a.drop('Approved', axis = 1)

full_lr = LogisticRegression()
full_lr.fit(X, approval)

print(full_lr.intercept_)
print(full_lr.coef_)
# Out:
# [-2.98826045]
# [[ 0.00646776 -0.0126677   0.00517144  0.14101022  3.33801641  0.12875893
#    1.21567412 -0.09579671  0.3539641 ]]

# %% [markdown]
# **Discussion:** Interpret the coefficients `model.coef_`. You may find it helpful to convert the output from sklearn back into a pandas Series with an index. Try to use language that you think would be understandable by a general audience.

# %% [markdown]
# Your answer:

# %% [markdown]
# ## D. How many of these coefficients are meaningful?
#
# How likely is it that some of these coefficients could have arisen by chance? We'd like to find confidence intervals for each coefficient.
#
# **Excercise 07:** Write a bootstrap function to generate the sampling distribution of all of the coefficients. On each bootstrap iteration, we'd like to store the values of the intercept and all of the coefficients in one row of a dataframe. We'll then be able to plot distribution of the dataframe, and compute confidence intervals from the marginal distributions. We suggest you follow the pattern in the previous lab, and write:
# 1. A function that takes a dataframe with the same column names as the credit approval dataset, fits a logistic regression model to the dataset and returns a pandas series containing the intercept and coefficients from the logistic regression
# 2. A bootstrap function that takes the above function as an `estimator` argument, and, on each bootstrap replication, stores the coefficients in the row of a data frame. It should return the bootstrap samples as a dataframe with an `Intercept` column and then one column for each independent variable. The function doesn't need to return the quantiles or the bootstrap standard error. Note that the column types of the data frame should be `float`.
#
# You can test the first function by making sure it gives you the same results as when you ran the logistic regression on the credit dataset above.  Once you've written the function, try it out on the credit dataset. You can use the `.quantile()` function on the returned data frame to compute the quantiles. You can also look at a pairplot of the bootstrap samples.
#
# **Remark:** You may need to set the `max_iter=1000` for the `LogisticRegression()`, as otherwise the model won't converge.

# %%
# Your code
def lr_regression(df):
    approval = df['Approved']
    X = df.drop('Approved', axis = 1)

    full_lr = LogisticRegression(max_iter = 1000)
    full_lr.fit(X, approval)
    beta0, beta1 = full_lr.intercept_[0],full_lr.coef_[0]
    betas = np.insert(beta1, 0, beta0)
    return pd.Series(betas, index = ['Intercept','Coefficient 1','Coefficient 2','Coefficient 3',
                                    'Coefficient 4', 'Coefficient 5', 'Coefficient 6', 
                                    'Coefficient 7', 'Coefficient 8', 'Coefficient 9']).astype(float)



def bootstrap(df, estimator):
    
    bootstrap_sample = pd.DataFrame([], columns = ['Intercept','Coefficient 1','Coefficient 2','Coefficient 3',
                                    'Coefficient 4', 'Coefficient 5', 'Coefficient 6', 
                                    'Coefficient 7', 'Coefficient 8', 'Coefficient 9'])
    
    replication = 100
    for i in range(replication):
        sample = df.sample(len(df), replace = True)
        betas = estimator(sample)
        bootstrap_sample.loc[i] = betas.values
    
    return bootstrap_sample


bootstrap_parameters = bootstrap(c_a, lr_regression)

#Compute 95% confidence interval with bootstrapped data
percentiles = [2.5,97.5]

def compute_ci(col, percen):
    return np.percentile(col.values, percen)

for col in bootstrap_parameters.columns:
    ci = compute_ci(bootstrap_parameters[col],percentiles)
    print("95% confidence interval for {}: [{}, {}]".format(col, ci[0], ci[1]))
# Out:
# 95% confidence interval for Intercept: [-3.823895367559442, -2.217088233072509]
# 95% confidence interval for Coefficient 1: [-0.4820126750870353, 0.4420289936045886]
# 95% confidence interval for Coefficient 2: [-0.03406928748436439, 0.007597200970776292]
# 95% confidence interval for Coefficient 3: [-0.029172592170699594, 0.060280394842764644]
# 95% confidence interval for Coefficient 4: [0.06583866609490513, 0.26126241166323244]
# 95% confidence interval for Coefficient 5: [2.92055177932786, 3.9205734367498084]
# 95% confidence interval for Coefficient 6: [-0.4581351307744658, 0.5542803009897816]
# 95% confidence interval for Coefficient 7: [0.5143539711851173, 1.8468397165587653]
# 95% confidence interval for Coefficient 8: [-0.5304762373146866, 0.28538213718748795]
# 95% confidence interval for Coefficient 9: [0.21095132885470608, 0.5279029372750347]

# %% [markdown]
# **Discussion** What can you conclude from the quantiles? Are any of the relationships you identified earlier open to question, because they may have arisen by chance?

# %% [markdown]
# Your Answer:

# %% [markdown]
# **We need your help:** This is a new course. In order for us to improve the labs for the next iterations, and to make sure that the next labs are better, we need your feedback. Please fill out the following [form](https://forms.office.com/Pages/ResponsePage.aspx?id=sAafLmkWiUWHiRCgaTTcYZmGMCx4KxlMjSTITqjdcXpUQkI2TUdDR1UwU0NBRE80OFVUMVRZM09KQi4u).

# %% [markdown]
# ## E. Standardised quantities
#
# By setting `max_iter=1000` we were able to ensure that the fitting of the logistic regression model converged. An alternative approach would be to standardise quantities. We can standardise the independent variables and then try fitting logistic regression again. However, the resulting coefficients will themselves be standardised, so we'll need to transform them back, to obtain the true figures.
#
# **Optional Exercise:** *If you're keen*, we suggest you just standardise the continuous variables. After running the same bootstrap function as above on the transformed data you can transform the parameters back using the formulae $\beta_{Age} = \frac{b_{Age}}{s_{Age}}$, where $b_{Age}$ is the transformed coefficient returned when the bootstrap function is applied to the transformed data.

# %%
# Your code
c_a_standardized = c_a.copy()

standardizer = StandardScaler()
standardizer.fit(c_a_standardized[['Age','Debt', 'YearsEmployed','LogIncome']])

standardized_data = standardizer.transform(c_a_standardized[['Age','Debt', 'YearsEmployed','LogIncome']])
c_a_standardized['Age'] = standardized_data[:,0]                                   
c_a_standardized['Debt'] = standardized_data[:,1]                                   
c_a_standardized['YearsEmployed'] = standardized_data[:,2]
c_a_standardized['LogIncome'] = standardized_data[:,3]
                                   
standardized_bootstrap_parameters = bootstrap(c_a_standardized, lr_regression)


def unstandardization(df):
    s_df = np.std(df)
    
    df = df / s_df
    
    return df


standardized_bootstrap_parameters['Coefficient 1'] = unstandardization(standardized_bootstrap_parameters['Coefficient 1'])
standardized_bootstrap_parameters['Coefficient 2'] = unstandardization(standardized_bootstrap_parameters['Coefficient 2'])
standardized_bootstrap_parameters['Coefficient 3'] = unstandardization(standardized_bootstrap_parameters['Coefficient 3'])
standardized_bootstrap_parameters['Coefficient 8'] = unstandardization(standardized_bootstrap_parameters['Coefficient 8'])


percentiles = [2.5,97.5]

for col in standardized_bootstrap_parameters.columns:
    ci = compute_ci(standardized_bootstrap_parameters[col],percentiles)
    print("95% confidence interval for {}: [{}, {}]".format(col, ci[0], ci[1]))
# Out:
# 95% confidence interval for Intercept: [-3.2267864396081043, -2.1005754415375724]
# 95% confidence interval for Coefficient 1: [-1.8474680282139313, 1.7365971380787744]
# 95% confidence interval for Coefficient 2: [-3.1180346207935705, 0.6051321172969478]
# 95% confidence interval for Coefficient 3: [-1.6822314074323585, 2.2561831702665716]
# 95% confidence interval for Coefficient 4: [0.19583404483361586, 0.8700811141112711]
# 95% confidence interval for Coefficient 5: [2.9081590834951347, 3.8758762929456116]
# 95% confidence interval for Coefficient 6: [-0.5011830240674111, 0.7232864682907125]
# 95% confidence interval for Coefficient 7: [0.4640946693566674, 1.8773869021309664]
# 95% confidence interval for Coefficient 8: [-2.5616277605964, 1.3398342381644517]
# 95% confidence interval for Coefficient 9: [0.23729068105970014, 0.7306972916856754]
